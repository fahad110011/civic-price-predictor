# %% [markdown]
# <a href="https://colab.research.google.com/github/fahad110011/civic-price-predictor/blob/main/notebooks/01_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the filtered Civic data we pushed to GitHub
url = (
  "https://raw.githubusercontent.com/"
  "fahad110011/civic-price-predictor/"
  "main/data/raw/civic_raw.csv"
)
df = pd.read_csv(url)

# Quick check
df.head()
# Out:
#      year  odometer  condition transmission state  price
# 0  2020.0    9954.0       good        other    al  26590
# 1  2018.0   28942.0       good        other    al  18590
# 2  2018.0    7885.0       good        other    al  21590
# 3  1995.0  215000.0       good       manual    al   3500
# 4  2003.0  236890.0  excellent    automatic    al   3950

# %%
import pandas as pd

# Load the filtered Civic data we pushed to GitHub
url = (
  "https://raw.githubusercontent.com/"
  "fahad110011/civic-price-predictor/"
  "main/data/raw/civic_raw.csv"
)
df = pd.read_csv(url)

# Quick check
df.head()
# Out:
#      year  odometer  condition transmission state  price
# 0  2020.0    9954.0       good        other    al  26590
# 1  2018.0   28942.0       good        other    al  18590
# 2  2018.0    7885.0       good        other    al  21590
# 3  1995.0  215000.0       good       manual    al   3500
# 4  2003.0  236890.0  excellent    automatic    al   3950

# %%
# Example: drop zero-mile entries again (if any)
df = df[df['odometer'] > 0].copy()
